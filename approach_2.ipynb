# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 as cv

import tensorflow as tf
from tensorflow import keras, Tensor
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, Dense, Dropout, Flatten, AveragePooling2D, Input, ReLU, BatchNormalization, Add, MaxPool2D, GlobalMaxPool2D, TimeDistributed, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.compat.v1.keras.layers import CuDNNGRU


import math
import datetime

import glob
from keras_video import VideoFrameGenerator, SlidingFrameGenerator, SplitFrameGenerator
import keras_video.utils

# %%
IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 512, 512, 3  
IMAGE_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
INPUT_SHAPE = IMAGE_SIZE + (IMAGE_CHANNELS,)

BATCH_SIZE = 2
NBFRAME = 3

# %%
# use sub directories names as classes
classes = [i.split(os.path.sep)[2] for i in glob.glob('./RLDD_fold_1_organized/*')]
classes.sort()
print(classes)
# Out:
# ['alert', 'drowsy', 'low_vagilant']

# %%
# pattern to get videos and classes
glob_pattern='/media/data/determined/workdir/mosa274994/RLDD_fold_1_organized/{classname}/*.mp4'
glob_pattern
# Out:
# '/media/data/determined/workdir/mosa274994/RLDD_fold_1_organized/{classname}/*.mp4'

# %%
# data_aug = ImageDataGenerator(
#     # validation_split=0.3,
#     # zoom_range=0.1,
#     # horizontal_flip=True,
#     # vertical_flip=True,
#     # rotation_range=90)
#     rescale=1./255)

# %%
train = SplitFrameGenerator(
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split_val=.4, 
    shuffle=True,
    classes=classes,
    batch_size=BATCH_SIZE,
    target_shape=IMAGE_SIZE,
    nb_channel=IMAGE_CHANNELS,
    # transformation=data_aug,
    use_frame_cache=True)
# Out:
# Total data: 3 classes for 18 files for train

# %%
valid = train.get_validation_generator()
# Out:
# Total data: 3 classes for 0 files for validation

# %%
len(train)
# Out:
# 0

# %%
len(valid)
# Out:
# 0

# %%
keras_video.utils.show_sample(train, random=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 keras_video.utils.show_sample(train, random=True)
#
# File /opt/conda/lib/python3.8/site-packages/keras_video/utils.py:27, in show_sample(g, index, random, row_width, row_height)
#      25 total = len(g)
#      26 if random:
# ---> 27     sample = secrets.randbelow(total)
#      28 else:
#      29     sample = index
#
# File /opt/conda/lib/python3.8/secrets.py:30, in randbelow(exclusive_upper_bound)
#      28 """Return a random int in the range [0, n)."""
#      29 if exclusive_upper_bound <= 0:
# ---> 30     raise ValueError("Upper bound must be positive.")
#      31 return _sysrand._randbelow(exclusive_upper_bound)
#
# ValueError: Upper bound must be positive.

# %%
def build_convnet(shape=(112, 112, 3)):
    momentum = .9
    model = keras.Sequential()
    model.add(Conv2D(64, (3,3), input_shape=shape,
        padding='same', activation='relu'))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    # flatten...
    model.add(GlobalMaxPool2D())
    return model

def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(CuDNNGRU(64))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
INSHAPE = (NBFRAME,) + IMAGE_SIZE + (IMAGE_CHANNELS,) # (5, 112, 112, 3)
INSHAPE
# Out:
# (500, 512, 512, 3)

# %%
model = action_model(INSHAPE, len(classes))
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc', 'mse']
)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_1 (TimeDis  (None, 500, 512)         4689216
#  tributed)
#
#  cu_dnngru_1 (CuDNNGRU)      (None, 64)                110976
#
#  dense_5 (Dense)             (None, 1024)              66560
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 128)               65664
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 5,465,667
# Trainable params: 5,463,747
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
EPOCHS=50
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=4),
    keras.callbacks.ModelCheckpoint(
        './chkp/weights.{epoch:02d}.hdf5',
        verbose=1),
]

steps_per_epoch_train = np.ceil(9 / BATCH_SIZE)
steps_per_epoch_valid = np.ceil(3 / BATCH_SIZE)

print('steps per epoch (train): {}'.format(steps_per_epoch_train))
print('steps per epoch (valid): {}'.format(steps_per_epoch_valid))

model.fit(train,
        # steps_per_epoch=3,
        epochs=EPOCHS,
        validation_data=valid,
        # validation_steps=3,
        callbacks=callbacks,
        verbose=1)
# Out:
# steps per epoch (train): 5.0
# steps per epoch (valid): 2.0
# Epoch 1/50
# 2023-02-20 10:33:20.395224: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 62.50GiB (rounded to 67108864000)requested by op sequential_3/time_distributed_1/conv2d_8/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-02-20 10:33:20.395291: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-02-20 10:33:20.395309: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 116, Chunks in use: 115. 29.0KiB allocated for chunks. 28.8KiB in use in bin. 8.9KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395322: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 40, Chunks in use: 40. 21.5KiB allocated for chunks. 21.5KiB in use in bin. 21.5KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395334: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 35, Chunks in use: 35. 38.5KiB allocated for chunks. 38.5KiB in use in bin. 38.0KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395347: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 34, Chunks in use: 34. 69.2KiB allocated for chunks. 69.2KiB in use in bin. 68.0KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395360: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 12, Chunks in use: 12. 64.5KiB allocated for chunks. 64.5KiB in use in bin. 64.5KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395371: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395382: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395396: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 12, Chunks in use: 12. 494.5KiB allocated for chunks. 494.5KiB in use in bin. 480.0KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395407: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395419: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 4, Chunks in use: 4. 576.0KiB allocated for chunks. 576.0KiB in use in bin. 576.0KiB client-requested in use in bin.
# 2023-02-20 10:33:20.395432: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 28, Chunks in use: 27. 8.45MiB allocated for chunks. 8.03MiB in use in bin. 7.64MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395445: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 6, Chunks in use: 6. 3.94MiB allocated for chunks. 3.94MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395456: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 6, Chunks in use: 6. 6.75MiB allocated for chunks. 6.75MiB in use in bin. 6.75MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395469: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 12, Chunks in use: 12. 26.00MiB allocated for chunks. 26.00MiB in use in bin. 25.50MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395481: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 6, Chunks in use: 6. 27.00MiB allocated for chunks. 27.00MiB in use in bin. 27.00MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395494: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 6, Chunks in use: 6. 63.00MiB allocated for chunks. 63.00MiB in use in bin. 54.00MiB client-requested in use in bin.
# 2023-02-20 10:33:20.395505: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395516: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395527: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395538: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-20 10:33:20.395550: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 3, Chunks in use: 1. 10.02GiB allocated for chunks. 2.93GiB in use in bin. 2.93GiB client-requested in use in bin.
# 2023-02-20 10:33:20.395562: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 62.50GiB was 256.00MiB, Chunk State:
# 2023-02-20 10:33:20.395587: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 2.93GiB | Requested Size: 2.93GiB | in_use: 0 | bin_num: 20, prev:   Size: 433.5KiB | Requested Size: 433.5KiB | in_use: 1 | bin_num: -1, next:   Size: 2.93GiB | Requested Size: 2.93GiB | in_use: 1 | bin_num: -1
# 2023-02-20 10:33:20.395601: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 4.16GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 2.93GiB | Requested Size: 2.93GiB | in_use: 1 | bin_num: -1
# 2023-02-20 10:33:20.395609: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 10899881984
# 2023-02-20 10:33:20.395621: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000000 of size 256 next 1
# 2023-02-20 10:33:20.395630: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000100 of size 1280 next 2
# 2023-02-20 10:33:20.395638: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000600 of size 256 next 3
# 2023-02-20 10:33:20.395646: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000700 of size 256 next 4
# 2023-02-20 10:33:20.395654: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000800 of size 256 next 5
# 2023-02-20 10:33:20.395662: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000900 of size 256 next 6
# 2023-02-20 10:33:20.395670: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000a00 of size 256 next 9
# 2023-02-20 10:33:20.395678: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000b00 of size 256 next 10
# 2023-02-20 10:33:20.395686: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000c00 of size 256 next 11
# 2023-02-20 10:33:20.395694: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000d00 of size 256 next 14
# 2023-02-20 10:33:20.395702: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000e00 of size 256 next 15
# 2023-02-20 10:33:20.395710: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba000f00 of size 256 next 16
# 2023-02-20 10:33:20.395718: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001000 of size 256 next 17
# 2023-02-20 10:33:20.395725: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001100 of size 256 next 18
# 2023-02-20 10:33:20.395733: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001200 of size 256 next 19
# 2023-02-20 10:33:20.395741: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001300 of size 256 next 20
# 2023-02-20 10:33:20.395751: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001400 of size 512 next 23
# 2023-02-20 10:33:20.395759: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001600 of size 256 next 24
# 2023-02-20 10:33:20.395767: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001700 of size 256 next 25
# 2023-02-20 10:33:20.395775: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001800 of size 512 next 26
# 2023-02-20 10:33:20.395783: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001a00 of size 512 next 29
# 2023-02-20 10:33:20.395791: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001c00 of size 512 next 30
# 2023-02-20 10:33:20.395799: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba001e00 of size 512 next 31
# 2023-02-20 10:33:20.395807: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002000 of size 512 next 32
# 2023-02-20 10:33:20.395815: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002200 of size 256 next 33
# 2023-02-20 10:33:20.395823: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002300 of size 256 next 34
# 2023-02-20 10:33:20.395831: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002400 of size 1024 next 37
# 2023-02-20 10:33:20.395840: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002800 of size 256 next 38
# 2023-02-20 10:33:20.395847: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002900 of size 256 next 39
# 2023-02-20 10:33:20.395855: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002a00 of size 1024 next 40
# 2023-02-20 10:33:20.395863: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba002e00 of size 1024 next 43
# 2023-02-20 10:33:20.395872: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba003200 of size 1024 next 44
# 2023-02-20 10:33:20.395880: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba003600 of size 1024 next 45
# 2023-02-20 10:33:20.395888: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba003a00 of size 1280 next 7
# 2023-02-20 10:33:20.395896: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba003f00 of size 6912 next 8
# 2023-02-20 10:33:20.395904: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba005a00 of size 256 next 46
# 2023-02-20 10:33:20.395911: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba005b00 of size 256 next 47
# 2023-02-20 10:33:20.395919: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba005c00 of size 2048 next 50
# 2023-02-20 10:33:20.395927: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba006400 of size 256 next 51
# 2023-02-20 10:33:20.395934: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba006500 of size 256 next 52
# 2023-02-20 10:33:20.395938: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba006600 of size 2048 next 53
# 2023-02-20 10:33:20.395942: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba006e00 of size 2048 next 56
# 2023-02-20 10:33:20.395946: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba007600 of size 2048 next 57
# 2023-02-20 10:33:20.395951: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba007e00 of size 2048 next 58
# 2023-02-20 10:33:20.395965: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba008600 of size 2048 next 59
# 2023-02-20 10:33:20.395973: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba008e00 of size 256 next 60
# 2023-02-20 10:33:20.395979: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba008f00 of size 256 next 61
# 2023-02-20 10:33:20.395986: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba009000 of size 256 next 62
# 2023-02-20 10:33:20.395993: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba009100 of size 256 next 63
# 2023-02-20 10:33:20.396001: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba009200 of size 32768 next 84
# 2023-02-20 10:33:20.396008: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba011200 of size 49152 next 119
# 2023-02-20 10:33:20.396015: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01d200 of size 256 next 125
# 2023-02-20 10:33:20.396021: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01d300 of size 768 next 126
# 2023-02-20 10:33:20.396027: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01d600 of size 256 next 127
# 2023-02-20 10:33:20.396033: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01d700 of size 6912 next 128
# 2023-02-20 10:33:20.396040: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f200 of size 256 next 129
# 2023-02-20 10:33:20.396046: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f300 of size 256 next 131
# 2023-02-20 10:33:20.396060: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f400 of size 256 next 132
# 2023-02-20 10:33:20.396066: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f500 of size 256 next 133
# 2023-02-20 10:33:20.396072: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f600 of size 512 next 135
# 2023-02-20 10:33:20.396079: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01f800 of size 512 next 137
# 2023-02-20 10:33:20.396084: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01fa00 of size 512 next 138
# 2023-02-20 10:33:20.396088: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01fc00 of size 512 next 139
# 2023-02-20 10:33:20.396092: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba01fe00 of size 1024 next 141
# 2023-02-20 10:33:20.396096: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba020200 of size 1024 next 143
# 2023-02-20 10:33:20.396101: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba020600 of size 1024 next 144
# 2023-02-20 10:33:20.396105: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba020a00 of size 1024 next 145
# 2023-02-20 10:33:20.396109: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba020e00 of size 2048 next 147
# 2023-02-20 10:33:20.396113: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba021600 of size 2048 next 149
# 2023-02-20 10:33:20.396116: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba021e00 of size 2048 next 150
# 2023-02-20 10:33:20.396120: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba022600 of size 2048 next 151
# 2023-02-20 10:33:20.396125: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba022e00 of size 1536 next 154
# 2023-02-20 10:33:20.396129: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba023400 of size 4096 next 155
# 2023-02-20 10:33:20.396133: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba024400 of size 2048 next 157
# 2023-02-20 10:33:20.396137: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba024c00 of size 512 next 159
# 2023-02-20 10:33:20.396141: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba024e00 of size 33792 next 67
# 2023-02-20 10:33:20.396145: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba02d200 of size 49152 next 70
# 2023-02-20 10:33:20.396149: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba039200 of size 1536 next 65
# 2023-02-20 10:33:20.396153: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba039800 of size 256 next 68
# 2023-02-20 10:33:20.396157: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba039900 of size 256 next 66
# 2023-02-20 10:33:20.396161: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba039a00 of size 4096 next 72
# 2023-02-20 10:33:20.396165: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03aa00 of size 256 next 73
# 2023-02-20 10:33:20.396169: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ab00 of size 256 next 74
# 2023-02-20 10:33:20.396173: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ac00 of size 2048 next 75
# 2023-02-20 10:33:20.396178: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03b400 of size 256 next 77
# 2023-02-20 10:33:20.396181: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03b500 of size 256 next 78
# 2023-02-20 10:33:20.396185: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03b600 of size 512 next 79
# 2023-02-20 10:33:20.396189: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03b800 of size 256 next 80
# 2023-02-20 10:33:20.396193: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03b900 of size 256 next 81
# 2023-02-20 10:33:20.396197: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ba00 of size 256 next 82
# 2023-02-20 10:33:20.396201: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03bb00 of size 256 next 83
# 2023-02-20 10:33:20.396205: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03bc00 of size 256 next 85
# 2023-02-20 10:33:20.396209: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03bd00 of size 256 next 86
# 2023-02-20 10:33:20.396213: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03be00 of size 256 next 87
# 2023-02-20 10:33:20.396216: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03bf00 of size 256 next 90
# 2023-02-20 10:33:20.396220: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c000 of size 256 next 91
# 2023-02-20 10:33:20.396224: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c100 of size 256 next 92
# 2023-02-20 10:33:20.396228: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c200 of size 256 next 93
# 2023-02-20 10:33:20.396232: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c300 of size 256 next 88
# 2023-02-20 10:33:20.396236: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c400 of size 768 next 89
# 2023-02-20 10:33:20.396240: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c700 of size 256 next 94
# 2023-02-20 10:33:20.396244: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c800 of size 256 next 95
# 2023-02-20 10:33:20.396247: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03c900 of size 256 next 96
# 2023-02-20 10:33:20.396251: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ca00 of size 6912 next 97
# 2023-02-20 10:33:20.396255: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03e500 of size 256 next 98
# 2023-02-20 10:33:20.396259: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03e600 of size 256 next 99
# 2023-02-20 10:33:20.396263: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03e700 of size 256 next 100
# 2023-02-20 10:33:20.396267: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03e800 of size 256 next 101
# 2023-02-20 10:33:20.396271: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03e900 of size 512 next 103
# 2023-02-20 10:33:20.396275: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03eb00 of size 512 next 104
# 2023-02-20 10:33:20.396279: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ed00 of size 512 next 105
# 2023-02-20 10:33:20.396283: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03ef00 of size 512 next 106
# 2023-02-20 10:33:20.396287: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03f100 of size 1024 next 108
# 2023-02-20 10:33:20.396291: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03f500 of size 1024 next 110
# 2023-02-20 10:33:20.396294: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03f900 of size 1024 next 111
# 2023-02-20 10:33:20.396299: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba03fd00 of size 1024 next 112
# 2023-02-20 10:33:20.396303: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba040100 of size 2048 next 114
# 2023-02-20 10:33:20.396307: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba040900 of size 2048 next 115
# 2023-02-20 10:33:20.396311: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba041100 of size 2048 next 116
# 2023-02-20 10:33:20.396315: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba041900 of size 2048 next 117
# 2023-02-20 10:33:20.396319: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba042100 of size 1536 next 120
# 2023-02-20 10:33:20.396323: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba042700 of size 4096 next 121
# 2023-02-20 10:33:20.396327: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba043700 of size 2048 next 122
# 2023-02-20 10:33:20.396331: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba043f00 of size 512 next 124
# 2023-02-20 10:33:20.396335: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba044100 of size 39168 next 13
# 2023-02-20 10:33:20.396339: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba04da00 of size 147456 next 12
# 2023-02-20 10:33:20.396343: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba071a00 of size 294912 next 22
# 2023-02-20 10:33:20.396347: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba0b9a00 of size 294912 next 21
# 2023-02-20 10:33:20.396351: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba101a00 of size 262144 next 71
# 2023-02-20 10:33:20.396355: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba141a00 of size 262144 next 69
# 2023-02-20 10:33:20.396359: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba181a00 of size 262144 next 64
# 2023-02-20 10:33:20.396363: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba1c1a00 of size 393216 next 28
# 2023-02-20 10:33:20.396367: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba221a00 of size 589824 next 27
# 2023-02-20 10:33:20.396371: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba2b1a00 of size 294912 next 102
# 2023-02-20 10:33:20.396375: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba2f9a00 of size 884736 next 36
# 2023-02-20 10:33:20.396379: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba3d1a00 of size 1179648 next 35
# 2023-02-20 10:33:20.396383: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba4f1a00 of size 2359296 next 109
# 2023-02-20 10:33:20.396388: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba731a00 of size 2359296 next 42
# 2023-02-20 10:33:20.396392: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbba971a00 of size 2359296 next 41
# 2023-02-20 10:33:20.396396: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbabb1a00 of size 2097152 next 76
# 2023-02-20 10:33:20.396400: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbadb1a00 of size 1179648 next 107
# 2023-02-20 10:33:20.396404: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbaed1a00 of size 393216 next 118
# 2023-02-20 10:33:20.396408: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbaf31a00 of size 262144 next 123
# 2023-02-20 10:33:20.396412: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbaf71a00 of size 147456 next 130
# 2023-02-20 10:33:20.396416: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbaf95a00 of size 294912 next 134
# 2023-02-20 10:33:20.396420: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbafdda00 of size 49152 next 153
# 2023-02-20 10:33:20.396424: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbafe9a00 of size 294912 next 49
# 2023-02-20 10:33:20.396428: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbb031a00 of size 4718592 next 48
# 2023-02-20 10:33:20.396432: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbb4b1a00 of size 4718592 next 113
# 2023-02-20 10:33:20.396436: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbb931a00 of size 14155776 next 55
# 2023-02-20 10:33:20.396441: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbc6b1a00 of size 9437184 next 54
# 2023-02-20 10:33:20.396445: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbcfb1a00 of size 589824 next 136
# 2023-02-20 10:33:20.396449: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbd041a00 of size 1179648 next 140
# 2023-02-20 10:33:20.396453: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbd161a00 of size 2359296 next 142
# 2023-02-20 10:33:20.396457: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbd3a1a00 of size 4718592 next 146
# 2023-02-20 10:33:20.396461: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbd821a00 of size 9437184 next 148
# 2023-02-20 10:33:20.396465: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe121a00 of size 393216 next 152
# 2023-02-20 10:33:20.396469: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe181a00 of size 2097152 next 156
# 2023-02-20 10:33:20.396473: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe381a00 of size 262144 next 158
# 2023-02-20 10:33:20.396477: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c1a00 of size 256 next 160
# 2023-02-20 10:33:20.396481: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c1b00 of size 768 next 161
# 2023-02-20 10:33:20.396485: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c1e00 of size 256 next 162
# 2023-02-20 10:33:20.396489: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c1f00 of size 256 next 163
# 2023-02-20 10:33:20.396493: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2000 of size 256 next 164
# 2023-02-20 10:33:20.396498: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2100 of size 256 next 165
# 2023-02-20 10:33:20.396502: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2200 of size 256 next 166
# 2023-02-20 10:33:20.396506: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2300 of size 256 next 167
# 2023-02-20 10:33:20.396518: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2400 of size 256 next 168
# 2023-02-20 10:33:20.396528: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2500 of size 256 next 169
# 2023-02-20 10:33:20.396535: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2600 of size 256 next 170
# 2023-02-20 10:33:20.396540: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2700 of size 256 next 171
# 2023-02-20 10:33:20.396544: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2800 of size 256 next 172
# 2023-02-20 10:33:20.396548: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2900 of size 256 next 173
# 2023-02-20 10:33:20.396552: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2a00 of size 256 next 174
# 2023-02-20 10:33:20.396557: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2b00 of size 256 next 175
# 2023-02-20 10:33:20.396561: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2c00 of size 256 next 183
# 2023-02-20 10:33:20.396565: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2d00 of size 256 next 177
# 2023-02-20 10:33:20.396569: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2e00 of size 256 next 176
# 2023-02-20 10:33:20.396573: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c2f00 of size 256 next 182
# 2023-02-20 10:33:20.396577: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3000 of size 256 next 181
# 2023-02-20 10:33:20.396581: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3100 of size 512 next 187
# 2023-02-20 10:33:20.396585: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3300 of size 512 next 188
# 2023-02-20 10:33:20.396589: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3500 of size 512 next 191
# 2023-02-20 10:33:20.396593: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3700 of size 512 next 192
# 2023-02-20 10:33:20.396597: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3900 of size 512 next 193
# 2023-02-20 10:33:20.396601: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3b00 of size 512 next 194
# 2023-02-20 10:33:20.396605: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c3d00 of size 1024 next 197
# 2023-02-20 10:33:20.396609: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c4100 of size 1024 next 198
# 2023-02-20 10:33:20.396613: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c4500 of size 1024 next 201
# 2023-02-20 10:33:20.396617: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c4900 of size 1024 next 202
# 2023-02-20 10:33:20.396621: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c4d00 of size 1024 next 203
# 2023-02-20 10:33:20.396626: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c5100 of size 1024 next 204
# 2023-02-20 10:33:20.396630: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c5500 of size 3328 next 184
# 2023-02-20 10:33:20.396634: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c6200 of size 6912 next 180
# 2023-02-20 10:33:20.396638: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c7d00 of size 2048 next 207
# 2023-02-20 10:33:20.396642: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c8500 of size 2048 next 210
# 2023-02-20 10:33:20.396646: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c8d00 of size 2048 next 211
# 2023-02-20 10:33:20.396650: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c9500 of size 2048 next 212
# 2023-02-20 10:33:20.396654: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3c9d00 of size 2048 next 213
# 2023-02-20 10:33:20.396658: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ca500 of size 32768 next 226
# 2023-02-20 10:33:20.396662: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3d2500 of size 1536 next 253
# 2023-02-20 10:33:20.396669: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3d2b00 of size 4096 next 254
# 2023-02-20 10:33:20.396682: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3d3b00 of size 2048 next 255
# 2023-02-20 10:33:20.396704: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3d4300 of size 512 next 257
# 2023-02-20 10:33:20.396709: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3d4500 of size 32768 next 258
# 2023-02-20 10:33:20.396713: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3dc500 of size 256 next 259
# 2023-02-20 10:33:20.396718: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3dc600 of size 768 next 260
# 2023-02-20 10:33:20.396722: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3dc900 of size 256 next 261
# 2023-02-20 10:33:20.396726: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3dca00 of size 6912 next 262
# 2023-02-20 10:33:20.396730: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3de500 of size 256 next 263
# 2023-02-20 10:33:20.396735: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3de600 of size 256 next 265
# 2023-02-20 10:33:20.396739: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3de700 of size 256 next 266
# 2023-02-20 10:33:20.396743: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3de800 of size 256 next 267
# 2023-02-20 10:33:20.396747: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3de900 of size 512 next 269
# 2023-02-20 10:33:20.396752: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3deb00 of size 512 next 271
# 2023-02-20 10:33:20.396764: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ded00 of size 512 next 272
# 2023-02-20 10:33:20.396772: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3def00 of size 512 next 273
# 2023-02-20 10:33:20.396778: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3df100 of size 1024 next 275
# 2023-02-20 10:33:20.396784: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3df500 of size 1024 next 277
# 2023-02-20 10:33:20.396792: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3df900 of size 1024 next 278
# 2023-02-20 10:33:20.396798: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3dfd00 of size 1024 next 279
# 2023-02-20 10:33:20.396804: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3e0100 of size 2048 next 281
# 2023-02-20 10:33:20.396810: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3e0900 of size 2048 next 283
# 2023-02-20 10:33:20.396816: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3e1100 of size 2048 next 284
# 2023-02-20 10:33:20.396821: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3e1900 of size 2048 next 285
# 2023-02-20 10:33:20.396828: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3e2100 of size 50176 next 217
# 2023-02-20 10:33:20.396834: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ee500 of size 49152 next 220
# 2023-02-20 10:33:20.396840: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fa500 of size 1536 next 214
# 2023-02-20 10:33:20.396846: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fab00 of size 4096 next 219
# 2023-02-20 10:33:20.396853: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fbb00 of size 2048 next 221
# 2023-02-20 10:33:20.396859: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc300 of size 512 next 223
# 2023-02-20 10:33:20.396865: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc500 of size 256 next 224
# 2023-02-20 10:33:20.396872: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc600 of size 256 next 225
# 2023-02-20 10:33:20.396878: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc700 of size 256 next 227
# 2023-02-20 10:33:20.396884: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc800 of size 256 next 230
# 2023-02-20 10:33:20.396891: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fc900 of size 256 next 231
# 2023-02-20 10:33:20.396897: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fca00 of size 256 next 233
# 2023-02-20 10:33:20.396903: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fcb00 of size 256 next 234
# 2023-02-20 10:33:20.396909: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fcc00 of size 256 next 228
# 2023-02-20 10:33:20.396915: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fcd00 of size 768 next 229
# 2023-02-20 10:33:20.396921: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fd000 of size 6912 next 232
# 2023-02-20 10:33:20.396928: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3feb00 of size 256 next 235
# 2023-02-20 10:33:20.396934: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fec00 of size 512 next 237
# 2023-02-20 10:33:20.396940: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3fee00 of size 512 next 238
# 2023-02-20 10:33:20.396947: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ff000 of size 512 next 239
# 2023-02-20 10:33:20.396953: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ff200 of size 512 next 240
# 2023-02-20 10:33:20.396960: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ff400 of size 1024 next 242
# 2023-02-20 10:33:20.396966: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ff800 of size 1024 next 244
# 2023-02-20 10:33:20.396972: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe3ffc00 of size 1024 next 245
# 2023-02-20 10:33:20.396978: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe400000 of size 1024 next 246
# 2023-02-20 10:33:20.396984: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe400400 of size 2048 next 248
# 2023-02-20 10:33:20.396989: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe400c00 of size 2048 next 249
# 2023-02-20 10:33:20.396996: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe401400 of size 2048 next 250
# 2023-02-20 10:33:20.397003: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe401c00 of size 2048 next 251
# 2023-02-20 10:33:20.397011: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe402400 of size 55552 next 178
# 2023-02-20 10:33:20.397018: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe40fd00 of size 147456 next 179
# 2023-02-20 10:33:20.397024: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe433d00 of size 294912 next 186
# 2023-02-20 10:33:20.397031: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe47bd00 of size 294912 next 185
# 2023-02-20 10:33:20.397038: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe4c3d00 of size 262144 next 215
# 2023-02-20 10:33:20.397044: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe503d00 of size 262144 next 218
# 2023-02-20 10:33:20.397050: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe543d00 of size 262144 next 216
# 2023-02-20 10:33:20.397057: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe583d00 of size 393216 next 190
# 2023-02-20 10:33:20.397064: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe5e3d00 of size 589824 next 189
# 2023-02-20 10:33:20.397071: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe673d00 of size 294912 next 236
# 2023-02-20 10:33:20.397077: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe6bbd00 of size 884736 next 196
# 2023-02-20 10:33:20.397084: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe793d00 of size 1179648 next 195
# 2023-02-20 10:33:20.397090: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbe8b3d00 of size 2359296 next 243
# 2023-02-20 10:33:20.397097: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbeaf3d00 of size 2359296 next 200
# 2023-02-20 10:33:20.397104: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbed33d00 of size 2359296 next 199
# 2023-02-20 10:33:20.397111: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbef73d00 of size 2097152 next 222
# 2023-02-20 10:33:20.397118: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf173d00 of size 1179648 next 241
# 2023-02-20 10:33:20.397124: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf293d00 of size 393216 next 252
# 2023-02-20 10:33:20.397131: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf2f3d00 of size 262144 next 256
# 2023-02-20 10:33:20.397137: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf333d00 of size 147456 next 264
# 2023-02-20 10:33:20.397144: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf357d00 of size 294912 next 268
# 2023-02-20 10:33:20.397151: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf39fd00 of size 1536 next 287
# 2023-02-20 10:33:20.397158: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf3a0300 of size 342528 next 206
# 2023-02-20 10:33:20.397165: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf3f3d00 of size 4718592 next 205
# 2023-02-20 10:33:20.397171: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbf873d00 of size 4718592 next 247
# 2023-02-20 10:33:20.397178: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbbfcf3d00 of size 14155776 next 209
# 2023-02-20 10:33:20.397184: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc0a73d00 of size 9437184 next 208
# 2023-02-20 10:33:20.397191: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc1373d00 of size 589824 next 270
# 2023-02-20 10:33:20.397203: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc1403d00 of size 1179648 next 274
# 2023-02-20 10:33:20.397210: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc1523d00 of size 2359296 next 276
# 2023-02-20 10:33:20.397218: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc1763d00 of size 4718592 next 280
# 2023-02-20 10:33:20.397225: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc1be3d00 of size 9437184 next 282
# 2023-02-20 10:33:20.397232: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc24e3d00 of size 393216 next 286
# 2023-02-20 10:33:20.397238: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2543d00 of size 4096 next 288
# 2023-02-20 10:33:20.397245: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2544d00 of size 2097152 next 289
# 2023-02-20 10:33:20.397255: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2744d00 of size 2048 next 290
# 2023-02-20 10:33:20.397262: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2745500 of size 262144 next 291
# 2023-02-20 10:33:20.397268: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2785500 of size 512 next 292
# 2023-02-20 10:33:20.397275: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc2785700 of size 32768 next 293
# 2023-02-20 10:33:20.397282: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278d700 of size 256 next 294
# 2023-02-20 10:33:20.397289: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278d800 of size 768 next 295
# 2023-02-20 10:33:20.397296: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278db00 of size 256 next 296
# 2023-02-20 10:33:20.397302: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278dc00 of size 256 next 297
# 2023-02-20 10:33:20.397309: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278dd00 of size 256 next 298
# 2023-02-20 10:33:20.397315: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278de00 of size 256 next 299
# 2023-02-20 10:33:20.397322: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278df00 of size 256 next 300
# 2023-02-20 10:33:20.397329: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e000 of size 256 next 301
# 2023-02-20 10:33:20.397336: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e100 of size 256 next 302
# 2023-02-20 10:33:20.397343: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e200 of size 256 next 303
# 2023-02-20 10:33:20.397349: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e300 of size 256 next 304
# 2023-02-20 10:33:20.397355: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e400 of size 256 next 305
# 2023-02-20 10:33:20.397362: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e500 of size 256 next 306
# 2023-02-20 10:33:20.397369: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e600 of size 256 next 307
# 2023-02-20 10:33:20.397375: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e700 of size 256 next 308
# 2023-02-20 10:33:20.397382: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e800 of size 256 next 310
# 2023-02-20 10:33:20.397392: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc278e900 of size 256 next 309
# 2023-02-20 10:33:20.397399: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278ea00 of size 256 next 313
# 2023-02-20 10:33:20.397406: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278eb00 of size 256 next 312
# 2023-02-20 10:33:20.397412: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc278ec00 of size 441344 next 314
# 2023-02-20 10:33:20.397419: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fa800 of size 256 next 315
# 2023-02-20 10:33:20.397425: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fa900 of size 256 next 316
# 2023-02-20 10:33:20.397431: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27faa00 of size 256 next 317
# 2023-02-20 10:33:20.397442: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fab00 of size 443904 next 318
# 2023-02-20 10:33:20.397449: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc2867100 of size 3145728000 next 311
# 2023-02-20 10:33:20.397456: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdc7e067100 of size 3145728000 next 319
# 2023-02-20 10:33:20.397464: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdd39867100 of size 4465397504 next 18446744073709551615
# 2023-02-20 10:33:20.397471: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2023-02-20 10:33:20.397488: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 115 Chunks of size 256 totalling 28.8KiB
# 2023-02-20 10:33:20.397499: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 34 Chunks of size 512 totalling 17.0KiB
# 2023-02-20 10:33:20.397507: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 768 totalling 4.5KiB
# 2023-02-20 10:33:20.397518: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 27 Chunks of size 1024 totalling 27.0KiB
# 2023-02-20 10:33:20.397526: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 1280 totalling 2.5KiB
# 2023-02-20 10:33:20.397534: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 1536 totalling 9.0KiB
# 2023-02-20 10:33:20.397543: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 33 Chunks of size 2048 totalling 66.0KiB
# ...
# 2023-02-20 10:33:30.406161: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e500 of size 256 next 306
# 2023-02-20 10:33:30.406168: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e600 of size 256 next 307
# 2023-02-20 10:33:30.406174: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e700 of size 256 next 308
# 2023-02-20 10:33:30.406181: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278e800 of size 256 next 310
# 2023-02-20 10:33:30.406188: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc278e900 of size 256 next 309
# 2023-02-20 10:33:30.406195: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278ea00 of size 256 next 313
# 2023-02-20 10:33:30.406203: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc278eb00 of size 256 next 312
# 2023-02-20 10:33:30.406210: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc278ec00 of size 441344 next 314
# 2023-02-20 10:33:30.406217: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fa800 of size 256 next 315
# 2023-02-20 10:33:30.406224: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fa900 of size 256 next 316
# 2023-02-20 10:33:30.406231: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27faa00 of size 256 next 317
# 2023-02-20 10:33:30.406238: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdbc27fab00 of size 443904 next 318
# 2023-02-20 10:33:30.406245: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdbc2867100 of size 3145728000 next 311
# 2023-02-20 10:33:30.406252: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fdc7e067100 of size 3145728000 next 319
# 2023-02-20 10:33:30.406259: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fdd39867100 of size 4465397504 next 18446744073709551615
# 2023-02-20 10:33:30.406266: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2023-02-20 10:33:30.406283: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 115 Chunks of size 256 totalling 28.8KiB
# 2023-02-20 10:33:30.406295: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 34 Chunks of size 512 totalling 17.0KiB
# 2023-02-20 10:33:30.406304: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 768 totalling 4.5KiB
# 2023-02-20 10:33:30.406312: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 27 Chunks of size 1024 totalling 27.0KiB
# 2023-02-20 10:33:30.406320: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 1280 totalling 2.5KiB
# 2023-02-20 10:33:30.406329: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 1536 totalling 9.0KiB
# 2023-02-20 10:33:30.406338: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 33 Chunks of size 2048 totalling 66.0KiB
# 2023-02-20 10:33:30.406346: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3328 totalling 3.2KiB
# 2023-02-20 10:33:30.406354: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 4096 totalling 24.0KiB
# 2023-02-20 10:33:30.406362: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 6912 totalling 40.5KiB
# 2023-02-20 10:33:30.406371: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 32768 totalling 128.0KiB
# 2023-02-20 10:33:30.406380: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 33792 totalling 33.0KiB
# 2023-02-20 10:33:30.406389: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 39168 totalling 38.2KiB
# 2023-02-20 10:33:30.406397: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 49152 totalling 192.0KiB
# 2023-02-20 10:33:30.406405: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 50176 totalling 49.0KiB
# 2023-02-20 10:33:30.406413: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 55552 totalling 54.2KiB
# 2023-02-20 10:33:30.406422: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 147456 totalling 576.0KiB
# 2023-02-20 10:33:30.406430: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 10 Chunks of size 262144 totalling 2.50MiB
# 2023-02-20 10:33:30.406439: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 294912 totalling 2.53MiB
# 2023-02-20 10:33:30.406447: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 342528 totalling 334.5KiB
# 2023-02-20 10:33:30.406456: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 393216 totalling 2.25MiB
# 2023-02-20 10:33:30.406464: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 443904 totalling 433.5KiB
# 2023-02-20 10:33:30.406473: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 589824 totalling 2.25MiB
# 2023-02-20 10:33:30.406482: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 884736 totalling 1.69MiB
# 2023-02-20 10:33:30.406490: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 1179648 totalling 6.75MiB
# 2023-02-20 10:33:30.406498: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 2097152 totalling 8.00MiB
# 2023-02-20 10:33:30.406506: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 8 Chunks of size 2359296 totalling 18.00MiB
# 2023-02-20 10:33:30.406514: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 4718592 totalling 27.00MiB
# 2023-02-20 10:33:30.406523: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 9437184 totalling 36.00MiB
# 2023-02-20 10:33:30.406532: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 14155776 totalling 27.00MiB
# 2023-02-20 10:33:30.406540: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3145728000 totalling 2.93GiB
# 2023-02-20 10:33:30.406547: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 3.06GiB
# 2023-02-20 10:33:30.406555: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 10899881984 memory_limit_: 10899881984 available bytes: 0 curr_region_allocation_bytes_: 21799763968
# 2023-02-20 10:33:30.406568: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     10899881984
# InUse:                      3288314880
# MaxInUse:                   6434042880
# NumAllocs:                         447
# MaxAllocSize:               6291456000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-02-20 10:33:30.406593: W tensorflow/core/common_runtime/bfc_allocator.cc:474] **____________________________******************************________________________________________
# 2023-02-20 10:33:30.406639: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at conv_ops.cc:684 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1000,64,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [31], in <cell line: 18>()
#      15 print('steps per epoch (train): {}'.format(steps_per_epoch_train))
#      16 print('steps per epoch (valid): {}'.format(steps_per_epoch_valid))
# ---> 18 model.fit(train,
#      19         # steps_per_epoch=3,
#      20         epochs=EPOCHS,
#      21         validation_data=valid,
#      22         # validation_steps=3,
#      23         callbacks=callbacks,
#      24         verbose=1)
#
# File /opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'sequential_3/time_distributed_1/conv2d_8/Conv2D' defined at (most recent call last):
#     File "/opt/conda/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/opt/conda/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/opt/conda/lib/python3.8/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 504, in dispatch_queue
#       await self.process_one()
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 493, in process_one
#       await dispatch(*args)
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#       await result
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 724, in execute_request
#       reply_content = await reply_content
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/opt/conda/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#       result = self._run_cell(
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#       return runner(coro)
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_3876/1290539931.py", line 18, in <cell line: 18>
#       model.fit(train,
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/training.py", line 1384, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/training.py", line 1021, in train_function
#       return step_function(self, iterator)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/training.py", line 1010, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/training.py", line 1000, in run_step
#       outputs = model.train_step(data)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/training.py", line 859, in train_step
#       y_pred = self(x, training=True)
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/sequential.py", line 374, in call
#       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/functional.py", line 451, in call
#       return self._run_internal_graph(
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1101, in __call__
#       self._set_mask_metadata(inputs, outputs, input_masks, not eager)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/base_layer.py", line 2573, in _set_mask_metadata
#       output_masks = self.compute_mask(inputs, previous_mask)
#     File "/opt/conda/lib/python3.8/site-packages/keras/layers/wrappers.py", line 343, in compute_mask
#       output_mask = self.layer.compute_mask(inner_inputs, inner_mask)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/sequential.py", line 407, in compute_mask
#       outputs = self.call(inputs, mask=mask)  # pylint: disable=unexpected-keyword-arg
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/sequential.py", line 374, in call
#       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/functional.py", line 451, in call
#       return self._run_internal_graph(
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/conda/lib/python3.8/site-packages/keras/layers/convolutional.py", line 248, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "/opt/conda/lib/python3.8/site-packages/keras/layers/convolutional.py", line 233, in convolution_op
#       return tf.nn.convolution(
# Node: 'sequential_3/time_distributed_1/conv2d_8/Conv2D'
# OOM when allocating tensor with shape[1000,64,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential_3/time_distributed_1/conv2d_8/Conv2D}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_6879]
